# %%
import os

print("Mempersiapkan lingkungan dan membuat folder di penyimpanan sementara...")

os.makedirs('/content/minecraft/worlds', exist_ok=True)
os.makedirs('/content/minecraft/behavior_packs', exist_ok=True)
os.makedirs('/content/minecraft/resource_packs', exist_ok=True)

os.chdir('/content/minecraft')

print(f"Folder kerja sementara dibuat di: {os.getcwd()}")
print("💡 Semua file akan dibuat di penyimpanan sementara dan diarsipkan sebagai NewWorld.zip.")
print("💡 File zip akan tersedia untuk download manual dari panel file Colab.")
# Out:
# Mempersiapkan lingkungan dan membuat folder di penyimpanan sementara...
# Folder kerja sementara dibuat di: /content/minecraft
# 💡 Semua file akan dibuat di penyimpanan sementara dan diarsipkan sebagai NewWorld.zip.
# 💡 File zip akan tersedia untuk download manual dari panel file Colab.

# %%
print("Memulai proses pengunduhan...")

# !pip install gdown --quiet

print("\n[1/2] Mengunduh mod 'Actions and Stuff 1.2 BY RAFLYMC.mcpack'...")
# !gdown --id 1rlJ3g9T6oTB8BvP9wUWn-vprECIuCNuD -O "Actions and Stuff 1.2 BY RAFLYMC.mcpack"

print("\n[2/2] Mengunduh file server resmi 'bedrock-server-1.21.93.1.zip'...")
# !wget -q -O bedrock-server.zip --show-progress "https://www.minecraft.net/bedrockdedicatedserver/bin-linux/bedrock-server-1.21.93.1.zip"

print("\nSemua file berhasil diunduh ke penyimpanan sementara.")
# Out:
# Memulai proses pengunduhan...
#
# [1/2] Mengunduh mod 'Actions and Stuff 1.2 BY RAFLYMC.mcpack'...
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1rlJ3g9T6oTB8BvP9wUWn-vprECIuCNuD
# From (redirected): https://drive.google.com/uc?id=1rlJ3g9T6oTB8BvP9wUWn-vprECIuCNuD&confirm=t&uuid=b8c44a6a-57c7-4819-b655-cab14480c53c
# To: /content/minecraft/Actions and Stuff 1.2 BY RAFLYMC.mcpack
# 100% 32.3M/32.3M [00:00<00:00, 77.1MB/s]
#
# [2/2] Mengunduh file server resmi 'bedrock-server-1.21.93.1.zip'...
# bedrock-server.zip  100%[===================>]  65.29M   122MB/s    in 0.5s
#
# Semua file berhasil diunduh ke penyimpanan sementara.

# %%
import zipfile
import shutil

print("Mengekstrak file server di penyimpanan sementara...")
# !unzip -q -o bedrock-server.zip

mod_filename = "Actions and Stuff 1.2 BY RAFLYMC.mcpack"
print(f"\nMemproses dan mengekstrak file mod '{mod_filename}'...")

mod_target_folder_name = "ActionsAndStuff_ByRaflyMC"
behavior_pack_path = os.path.join('./behavior_packs', mod_target_folder_name)
resource_pack_path = os.path.join('./resource_packs', mod_target_folder_name)

os.makedirs(behavior_pack_path, exist_ok=True)

with zipfile.ZipFile(mod_filename, 'r') as zip_ref:
    zip_ref.extractall(behavior_pack_path)

print(f"✅ Mod 'Actions and Stuff' berhasil diekstrak sebagai Behavior Pack ke: {behavior_pack_path}")

if os.path.exists(resource_pack_path):
    shutil.rmtree(resource_pack_path)
shutil.copytree(behavior_pack_path, resource_pack_path)

print(f"✅ Mod 'Actions and Stuff' berhasil disalin sebagai Resource Pack ke: {resource_pack_path}")

print("\n🔍 Debug - Struktur folder behavior_packs:")
# !ls -R ./behavior_packs/ActionsAndStuff_ByRaflyMC | head -n 15

print("\n🔍 Debug - Struktur folder resource_packs:")
# !ls -R ./resource_packs/ActionsAndStuff_ByRaflyMC | head -n 15

print("\n🧹 Membersihkan file arsip...")
try:
    os.remove("bedrock-server.zip")
    os.remove(mod_filename)
except FileNotFoundError:
    print("   File arsip sudah dihapus atau tidak ditemukan.")

print("\n✅ Proses ekstraksi selesai!")
# Out:
# Mengekstrak file server di penyimpanan sementara...
#
# Memproses dan mengekstrak file mod 'Actions and Stuff 1.2 BY RAFLYMC.mcpack'...
# ✅ Mod 'Actions and Stuff' berhasil diekstrak sebagai Behavior Pack ke: ./behavior_packs/ActionsAndStuff_ByRaflyMC
# ✅ Mod 'Actions and Stuff' berhasil disalin sebagai Resource Pack ke: ./resource_packs/ActionsAndStuff_ByRaflyMC
#
# 🔍 Debug - Struktur folder behavior_packs:
# ./behavior_packs/ActionsAndStuff_ByRaflyMC:
# animation_controllers
# animations
# attachables
# entity
# manifest.json
# materials
# models
# pack_icon.png
# particles
# render_controllers
# sounds
# sounds.json
# splashes.json
# subpacks
#
# 🔍 Debug - Struktur folder resource_packs:
# ./resource_packs/ActionsAndStuff_ByRaflyMC:
# animation_controllers
# animations
# attachables
# entity
# manifest.json
# materials
# models
# pack_icon.png
# particles
# render_controllers
# sounds
# sounds.json
# splashes.json
# subpacks
#
# 🧹 Membersihkan file arsip...
#
# ✅ Proses ekstraksi selesai!

# %%
import json

print("Mengkonfigurasi behavior pack dan resource pack untuk dunia...")

behavior_pack_folder = '/content/minecraft/behavior_packs'
resource_pack_folder = '/content/minecraft/resource_packs'
valid_packs_file = '/content/minecraft/valid_known_packs.json'
world_name = "NewWorld"
world_folder = f'/content/minecraft/worlds/{world_name}'

mod_folder_name_to_find = "ActionsAndStuff_ByRaflyMC"

if os.path.exists(world_folder):
    print(f"\n🧹 Menghapus dunia lama '{world_name}' untuk memastikan mod aktif...")
    shutil.rmtree(world_folder)
os.makedirs(world_folder, exist_ok=True)

valid_packs_config = []
world_behavior_packs = []
world_resource_packs = []

def process_packs(pack_directory, pack_type):
    print(f"\n📦 Mencari {pack_type} packs...")
    for root, dirs, files in os.walk(pack_directory):
        if 'manifest.json' in files:
            manifest_path = os.path.join(root, 'manifest.json')
            try:
                with open(manifest_path, 'r') as f:
                    manifest_data = json.load(f)

                header = manifest_data.get('header', {})
                pack_id = header.get('uuid')
                version = header.get('version')
                name = header.get('name', 'Unknown')

                if not pack_id or not version:
                    continue

                print(f"   🔎 Ditemukan Pack: {name} ({os.path.basename(root)})")

                valid_packs_config.append({
                    "pack_id": pack_id,
                    "version": version,
                    "file_system": "RawPath",
                })

                if os.path.basename(root) == mod_folder_name_to_find:
                    print(f"   ✅ Ditemukan MOD KUSTOM! Mengaktifkan '{name}' untuk dunia.")
                    pack_to_activate = {"pack_id": pack_id, "version": version}
                    if pack_type == 'behavior' and pack_to_activate not in world_behavior_packs:
                        world_behavior_packs.append(pack_to_activate)
                    elif pack_type == 'resource' and pack_to_activate not in world_resource_packs:
                        world_resource_packs.append(pack_to_activate)

            except Exception as e:
                print(f"   ❌ Error membaca manifest di {manifest_path}: {e}")

process_packs(behavior_pack_folder, 'behavior')
process_packs(resource_pack_folder, 'resource')

if world_behavior_packs or world_resource_packs:
    print(f"\n📄 Membuat file konfigurasi...")

    with open(valid_packs_file, 'w') as f:
        json.dump(valid_packs_config, f, indent=2)
    print(f"   ✅ {valid_packs_file} dibuat dengan {len(valid_packs_config)} total pack(s) yang diketahui.")

    if world_behavior_packs:
        world_behavior_packs_file = os.path.join(world_folder, 'world_behavior_packs.json')
        with open(world_behavior_packs_file, 'w') as f:
            json.dump(world_behavior_packs, f, indent=2)
        print(f"   ✅ {world_behavior_packs_file} dibuat dengan {len(world_behavior_packs)} behavior pack(s) aktif.")

    if world_resource_packs:
        world_resource_packs_file = os.path.join(world_folder, 'world_resource_packs.json')
        with open(world_resource_packs_file, 'w') as f:
            json.dump(world_resource_packs, f, indent=2)
        print(f"   ✅ {world_resource_packs_file} dibuat dengan {len(world_resource_packs)} resource pack(s) aktif.")

    leveldat_path = os.path.join(world_folder, 'level.dat')
    if not os.path.exists(leveldat_path):
        with open(leveldat_path, 'wb') as f: f.write(b'')
        print(f"   ✅ File level.dat placeholder dibuat.")

    print(f"\n🎉 Konfigurasi dunia selesai!")
    print(f"   World '{world_name}' telah dikonfigurasi dengan mod 'Actions and Stuff' di penyimpanan sementara.")
else:
    print("\n❌ Tidak ada mod kustom yang terdeteksi atau dikonfigurasi!")
    print(f"   Pastikan ada folder bernama '{mod_folder_name_to_find}' di dalam 'behavior_packs' dan/atau 'resource_packs'.")
# Out:
# Mengkonfigurasi behavior pack dan resource pack untuk dunia...
#
# 📦 Mencari behavior packs...
#    🔎 Ditemukan Pack: Experimental Creator Cameras (experimental_creator_cameras)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.18.30)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.20)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.80)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.17.40)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.17.20)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.50)
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry_1.21.10/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 436)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.0)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.80)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.10)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.70)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.90)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.40)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.14)
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 433)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.17.0)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.18.10)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.10)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.40)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.70)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.15)
#    🔎 Ditemukan Pack: resourcePack.experimental_jigsaw_structures.name (experimental_jigsaw_structures)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.80)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.17.30)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.60)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.20)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.60)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.0)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.30)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.10)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.30)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.16)
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry_1.21.30/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 436)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.16.100)
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry_1.20.50/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 436)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.16.200)
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry_1.21.20/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 436)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.16.220)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.21.93)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.18.0)
#    🔎 Ditemukan Pack: Villager Trade Rebalancing (experimental_villager_trade)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.0)
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry_1.20.60/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 436)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.30)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.17.10)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.40)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.50)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.20)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.50)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.18.20)
#    🔎 Ditemukan Pack: pack.name (ActionsAndStuff_ByRaflyMC)
#    ✅ Ditemukan MOD KUSTOM! Mengaktifkan 'pack.name' untuk dunia.
#    ❌ Error membaca manifest di /content/minecraft/behavior_packs/chemistry_1.21.0/manifest.json: Expecting property name enclosed in double quotes: line 20 column 7 (char 434)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.19.70)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.16.210)
#    🔎 Ditemukan Pack: resourcePack.vanilla_server.name (vanilla_1.20.60)
#
# 📦 Mencari resource packs...
#    🔎 Ditemukan Pack: resourcePack.vanilla.name (vanilla)
#    ❌ Error membaca manifest di /content/minecraft/resource_packs/chemistry/manifest.json: Expecting property name enclosed in double quotes: line 21 column 7 (char 463)
#    🔎 Ditemukan Pack: resourcePack.editor.client.name (editor)
#    🔎 Ditemukan Pack: pack.name (ActionsAndStuff_ByRaflyMC)
#    ✅ Ditemukan MOD KUSTOM! Mengaktifkan 'pack.name' untuk dunia.
#
# 📄 Membuat file konfigurasi...
#    ✅ /content/minecraft/valid_known_packs.json dibuat dengan 53 total pack(s) yang diketahui.
#    ✅ /content/minecraft/worlds/NewWorld/world_behavior_packs.json dibuat dengan 1 behavior pack(s) aktif.
#    ✅ /content/minecraft/worlds/NewWorld/world_resource_packs.json dibuat dengan 1 resource pack(s) aktif.
#    ✅ File level.dat placeholder dibuat.
#
# 🎉 Konfigurasi dunia selesai!
#    World 'NewWorld' telah dikonfigurasi dengan mod 'Actions and Stuff' di penyimpanan sementara.

# %%
server_properties_content = f"""
server-name=NewWorld Server with Mods
gamemode=survival
force-gamemode=false
difficulty=normal
allow-cheats=true
max-players=6
online-mode=true
allow-list=false
server-port=19133
server-portv6=19133
enable-lan-visibility=true
view-distance=32
tick-distance=4
player-idle-timeout=30
max-threads=8
level-name={world_name}
level-seed=-3899835130120818196
default-player-permission-level=member
texturepack-required=false
content-log-file-enabled=true
compression-threshold=1
compression-algorithm=zlib
server-authoritative-movement=server-auth
server-authoritative-block-breaking=true
player-movement-score-threshold=20
player-movement-action-direction-threshold=0.85
player-movement-distance-threshold=0.3
player-movement-duration-threshold-in-ms=500
correct-player-movement=false
server-authoritative-block-breaking-pick-range-scalar=1.5
chat-restriction=None
disable-player-interaction=false
client-side-chunk-generation-enabled=true
block-network-ids-are-hashes=true
disable-persona=false
disable-custom-skins=false
server-build-radius-ratio=Disabled
allow-outbound-script-debugging=false
allow-inbound-script-debugging=false
script-debugger-auto-attach=disabled
script-debugger-auto-listen=false
script-debugger-generate-documentation=false
"""

with open("/content/minecraft/server.properties", "w") as f:
    f.write(server_properties_content)

print("✅ File server.properties berhasil dibuat dan dikonfigurasi di penyimpanan sementara.")
print("\n--- KONFIGURASI PENTING ---")
print("1. ✅ Nama server: 'NewWorld Server with Mods'")
print("2. ✅ World name: 'NewWorld' (akan diunggah ke Google Drive)")
print("3. ✅ Cheats enabled: untuk command admin dan debugging")
print("4. ✅ Content logging: aktif untuk debugging pack")
print("5. ✅ Server authoritative movement: untuk kompatibilitas mod")
print("6. ⚠️  Semua file akan diunggah ke /content/drive/MyDrive/minecraft-server di langkah akhir")
# Out:
# ✅ File server.properties berhasil dibuat dan dikonfigurasi di penyimpanan sementara.
#
# --- KONFIGURASI PENTING ---
# 1. ✅ Nama server: 'NewWorld Server with Mods'
# 2. ✅ World name: 'NewWorld' (akan diunggah ke Google Drive)
# 3. ✅ Cheats enabled: untuk command admin dan debugging
# 4. ✅ Content logging: aktif untuk debugging pack
# 5. ✅ Server authoritative movement: untuk kompatibilitas mod
# 6. ⚠️  Semua file akan diunggah ke /content/drive/MyDrive/minecraft-server di langkah akhir

# %%
import urllib.request

os.chdir('/content/minecraft')

print("Mengunduh agen Playit.gg ke penyimpanan sementara...")
playit_url = "https://github.com/playit-cloud/playit-agent/releases/download/v0.15.26/playit-linux-amd64"
playit_path = "playit"
if not os.path.exists(playit_path):
    urllib.request.urlretrieve(playit_url, playit_path)
    os.chmod(playit_path, 0o755)

print("\n========================= TINDAKAN PENTING =========================")
print("Sel ini akan menjalankan Playit dan mungkin akan menampilkan URL.")
print("\nCARI BARIS YANG TERLIHAT SEPERTI INI:")
print("   'https://playit.gg/claim/...'")
print("\nJIKA ANDA MELIHAT URL DI ATAS:")
print("   1. Salin URL itu, buka di browser, dan selesaikan otorisasi.")
print("   2. Setelah selesai, KEMBALI ke sini dan HENTIKAN (tombol ■) eksekusi sel ini.")
print("   3. Lanjutkan ke sel berikutnya.")
print("\nJIKA ANDA TIDAK MELIHAT URL KLAIM dan langsung melihat info tunnel:")
print("   - Itu berarti Anda sudah terotorisasi.")
print("   - Cukup HENTIKAN (tombol ■) sel ini dan lanjutkan ke sel berikutnya.")
print("====================================================================\n")

# !./playit
# Out:
# Mengunduh agen Playit.gg ke penyimpanan sementara...
#
# ========================= TINDAKAN PENTING =========================
# Sel ini akan menjalankan Playit dan mungkin akan menampilkan URL.
#
# CARI BARIS YANG TERLIHAT SEPERTI INI:
#    'https://playit.gg/claim/...'
#
# JIKA ANDA MELIHAT URL DI ATAS:
#    1. Salin URL itu, buka di browser, dan selesaikan otorisasi.
#    2. Setelah selesai, KEMBALI ke sini dan HENTIKAN (tombol ■) eksekusi sel ini.
#    3. Lanjutkan ke sel berikutnya.
#
# JIKA ANDA TIDAK MELIHAT URL KLAIM dan langsung melihat info tunnel:
#    - Itu berarti Anda sudah terotorisasi.
#    - Cukup HENTIKAN (tombol ■) sel ini dan lanjutkan ke sel berikutnya.
# ====================================================================
#
# 8no command provided, doing auto run8Visit link to setup https://playit.gg/claim/3fc1607cb28Visit link to setup https://playit.gg/claim/3fc1607cb28Approve program at https://playit.gg/claim/3fc1607cb28Program approved :). Secret code being setup.8starting up tunnel connection8tunnel running8playit (v0.15.26): 1752046223170 tunnel running, 0 tunnels registered
#
#
# TUNNELS
# Add tunnels here: https://playit.gg/account/agents/7f660bf7-44bc-43ed-a612-8babb0e02482
# 8playit (v0.15.26): 1752046226259 tunnel running, 0 tunnels registered
#
#
# TUNNELS
# Add tunnels here: https://playit.gg/account/agents/7f660bf7-44bc-43ed-a612-8babb0e02482
# 8playit (v0.15.26): 1752046229365 tunnel running, 0 tunnels registered
#
#
# TUNNELS
# Add tunnels here: https://playit.gg/account/agents/7f660bf7-44bc-43ed-a612-8babb0e02482
# 8playit (v0.15.26): 1752046232455 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# from-lauren.gl.at.ply.gg:11340 => 127.0.0.1:19132 (minecraft-bedrock)
# 8playit (v0.15.26): 1752046235559 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# from-lauren.gl.at.ply.gg:11340 => 127.0.0.1:19132 (minecraft-bedrock)
# 8playit (v0.15.26): 1752046238653 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# from-lauren.gl.at.ply.gg:11340 => 127.0.0.1:19132 (minecraft-bedrock)
# 8playit (v0.15.26): 1752046241748 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# from-lauren.gl.at.ply.gg:11340 => 127.0.0.1:11340 (minecraft-bedrock)
# 8playit (v0.15.26): 1752046244838 tunnel running, 1 tunnels registered
#
#
# TUNNELS
# from-lauren.gl.at.ply.gg:11340 => 127.0.0.1:11340 (minecraft-bedrock)

# %%
import re

def update_server_properties_port(new_port):
    """Membaca file server.properties, mengubah server-port, dan menyimpannya kembali."""
    properties_file = '/content/minecraft/server.properties'
    print(f"\n⚙️  Mengubah port di '{properties_file}'...")

    if not os.path.exists(properties_file):
        print(f"   ❌ ERROR: File '{properties_file}' tidak ditemukan. Tidak dapat mengubah port.")
        return

    try:
        with open(properties_file, 'r') as f:
            lines = f.readlines()

        new_lines = []
        port_updated = False
        for line in lines:
            if line.strip().startswith('server-port='):
                new_line = f'server-port={new_port}\n'
                new_lines.append(new_line)
                print(f"   -> Mengganti baris: '{line.strip()}' -> '{new_line.strip()}'")
                port_updated = True
            else:
                new_lines.append(line)

        if not port_updated:
            print("   ⚠️  PERINGATAN: Baris 'server-port=' tidak ditemukan. Menambahkan di akhir file.")
            new_lines.append(f'\nserver-port={new_port}\n')

        with open(properties_file, 'w') as f:
            f.writelines(new_lines)

        print(f"   ✅ Port server berhasil diubah menjadi: {new_port}")

    except Exception as e:
        print(f"   ❌ Gagal mengubah file server.properties: {e}")

GUNAKAN_INPUT_MANUAL = False

print("Mencari alamat server dari Playit.gg...")
os.chdir('/content/minecraft')

server_address = None

def get_manual_address():
    print("\n--- INPUT MANUAL ALAMAT SERVER ---")
    print("Masukkan alamat dan port yang Anda dapatkan dari dasbor Playit.gg.")
    manual_address = input("Masukkan Alamat Server (contoh: random-name.ply.gg): ")
    manual_port = input("Masukkan Port Server (contoh: 12345): ")

    if manual_address and manual_port:
        update_server_properties_port(manual_port.strip())
        return f"{manual_address.strip()}:{manual_port.strip()}"
    else:
        return None

if GUNAKAN_INPUT_MANUAL:
    print("[INFO] Mode input manual diaktifkan.")
    server_address = get_manual_address()
else:
    print("[INFO] Mencoba deteksi otomatis dari file 'playit.log'...")
    try:
        with open("playit.log", "r") as f:
            log_content = f.read()
            match = re.search(r"(\S+\.ply\.gg:\d+)\s+=>", log_content)
            if match:
                server_address = match.group(1)
                port = server_address.split(':')[-1]
                update_server_properties_port(port)
                print("[OK] Alamat server dan port berhasil ditemukan secara otomatis.")
            else:
                print("\n[PERINGATAN] Gagal menemukan alamat server dari log secara otomatis.")
                server_address = get_manual_address()

    except FileNotFoundError:
        print("\n[ERROR] File 'playit.log' tidak ditemukan!")
        print("Harap jalankan sel sebelumnya terlebih dahulu dan HENTIKAN sel tersebut setelah mendapatkan informasi tunnel.")
        server_address = get_manual_address()

if server_address:
    print("\n" + "="*55)
    print("          ALAMAT SERVER ANDA (UNTUK DI-SHARE)")
    print(f"                   {server_address}")
    print("="*55 + "\n")
    print("✅ Catat atau salin alamat di atas. Gunakan alamat ini untuk masuk ke server di notebook lain.")
else:
    print("\n[GAGAL] Tidak ada alamat server yang bisa ditampilkan.")
    print("Pastikan Anda menjalankan sel sebelumnya, atau isi alamat secara manual saat diminta.")

print("\n--- PENJELASAN PENTING (Mengenai Port Server) ---")
print("Port di 'server.properties' telah diatur sesuai input Anda.")
print("Playit.gg bekerja sebagai 'terowongan' (tunnel):")
print(f"  - Pemain terhubung ke alamat publik: {server_address if server_address else 'Alamat.Playit:PortPublik'}")
print(f"  - Playit.gg kemudian meneruskan koneksi itu ke server Anda di port lokal yang telah Anda atur.")
print(f"  - File server.properties telah diperbarui dan akan dipindahkan ke Google Drive.")
# Out:
# Mencari alamat server dari Playit.gg...
# [INFO] Mencoba deteksi otomatis dari file 'playit.log'...
#
# [ERROR] File 'playit.log' tidak ditemukan!
# Harap jalankan sel sebelumnya terlebih dahulu dan HENTIKAN sel tersebut setelah mendapatkan informasi tunnel.
#
# --- INPUT MANUAL ALAMAT SERVER ---
# Masukkan alamat dan port yang Anda dapatkan dari dasbor Playit.gg.
# Masukkan Alamat Server (contoh: random-name.ply.gg): from-lauren.gl.at.ply.gg
# Masukkan Port Server (contoh: 12345): 11340
#
# ⚙️  Mengubah port di '/content/minecraft/server.properties'...
#    -> Mengganti baris: 'server-port=19133' -> 'server-port=11340'
#    ✅ Port server berhasil diubah menjadi: 11340
#
# =======================================================
#           ALAMAT SERVER ANDA (UNTUK DI-SHARE)
#                    from-lauren.gl.at.ply.gg:11340
# =======================================================
#
# ✅ Catat atau salin alamat di atas. Gunakan alamat ini untuk masuk ke server di notebook lain.
#
# --- PENJELASAN PENTING (Mengenai Port Server) ---
# Port di 'server.properties' telah diatur sesuai input Anda.
# Playit.gg bekerja sebagai 'terowongan' (tunnel):
#   - Pemain terhubung ke alamat publik: from-lauren.gl.at.ply.gg:11340
#   - Playit.gg kemudian meneruskan koneksi itu ke server Anda di port lokal yang telah Anda atur.
#   - File server.properties telah diperbarui dan akan dipindahkan ke Google Drive.

# %%
print("Mengarsipkan isi folder '/content/minecraft' menjadi file NewWorld.zip di penyimpanan sementara...")

source_dir = '/content/minecraft'
zip_filename = '/content/NewWorld.zip'

if os.path.exists(zip_filename):
    print(f"🧹 Menghapus file zip lama di {zip_filename}...")
    os.remove(zip_filename)

print(f"📦 Mengarsipkan semua file dan folder dari {source_dir} ke {zip_filename}...")
try:
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(source_dir):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, '/content')
                zipf.write(file_path, arcname)
    print(f"✅ File {zip_filename} berhasil dibuat.")
except Exception as e:
    print(f"❌ Gagal membuat file zip: {e}")
    print("Harap periksa ruang penyimpanan atau izin akses.")
    raise

print("\n🔍 Memverifikasi isi file zip:")
with zipfile.ZipFile(zip_filename, 'r') as zipf:
    zip_contents = zipf.namelist()
    print(f"✅ Total file dalam zip: {len(zip_contents)}")
    print("Contoh isi (maksimum 20 file):")
    for item in zip_contents[:20]:
        print(f"   - {item}")

key_files = [
    'minecraft/server.properties',
    'minecraft/valid_known_packs.json',
    'minecraft/playit',
    'minecraft/worlds/NewWorld/level.dat'
]
print("\n🔍 Memeriksa keberadaan file kunci dalam zip:")
for key_file in key_files:
    if key_file in zip_contents:
        print(f"✅ {key_file} ada dalam zip.")
    else:
        print(f"❌ {key_file} tidak ditemukan dalam zip!")

print("\n✅ Proses pengarsipan selesai!")
print(f"📍 File zip tersedia di: {zip_filename}")
print("💡 Anda dapat mendownload file 'NewWorld.zip' secara manual dari panel file Colab di /content.")
print("💡 Untuk mendownload, buka panel file di sebelah kiri Colab, temukan 'NewWorld.zip', klik kanan, dan pilih 'Download'.")
# Out:
# Mengarsipkan isi folder '/content/minecraft' menjadi file NewWorld.zip di penyimpanan sementara...
# 📦 Mengarsipkan semua file dan folder dari /content/minecraft ke /content/NewWorld.zip...
# ✅ File /content/NewWorld.zip berhasil dibuat.
#
# 🔍 Memverifikasi isi file zip:
# ✅ Total file dalam zip: 36899
# Contoh isi (maksimum 20 file):
#    - minecraft/bedrock_server
#    - minecraft/allowlist.json
#    - minecraft/permissions.json
#    - minecraft/valid_known_packs.json
#    - minecraft/playit
#    - minecraft/profanity_filter.wlist
#    - minecraft/release-notes.txt
#    - minecraft/bedrock_server_how_to.html
#    - minecraft/server.properties
#    - minecraft/config/default/permissions.json
#    - minecraft/definitions/attachables/iron_helmet.json
#    - minecraft/definitions/attachables/iron_chestplate.player.json
#    - minecraft/definitions/attachables/diamond_boots.json
#    - minecraft/definitions/attachables/chainmail_helmet.json
#    - minecraft/definitions/attachables/chainmail_leggings.player.json
#    - minecraft/definitions/attachables/netherite_boots.player.json
#    - minecraft/definitions/attachables/chainmail_leggings.json
#    - minecraft/definitions/attachables/shield.entity.json
#    - minecraft/definitions/attachables/diamond_chestplate.player.json
#    - minecraft/definitions/attachables/turtle_shell_helmet.json
#
# 🔍 Memeriksa keberadaan file kunci dalam zip:
# ✅ minecraft/server.properties ada dalam zip.
# ✅ minecraft/valid_known_packs.json ada dalam zip.
# ✅ minecraft/playit ada dalam zip.
# ✅ minecraft/worlds/NewWorld/level.dat ada dalam zip.
#
# ✅ Proses pengarsipan selesai!
# 📍 File zip tersedia di: /content/NewWorld.zip
# 💡 Anda dapat mendownload file 'NewWorld.zip' secara manual dari panel file Colab di /content.
# 💡 Untuk mendownload, buka panel file di sebelah kiri Colab, temukan 'NewWorld.zip', klik kanan, dan pilih 'Download'.
